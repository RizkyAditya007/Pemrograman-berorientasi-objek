# %% [markdown]
# <a href="https://colab.research.google.com/github/RizkyAditya007/Pemrograman-berorientasi-objek/blob/main/jobsheet_12(PBO)_Rizky_Aditya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Praktikum 1: Persiapan Data (CSV)

# %%
# %%writefile lokasi_semarang.csv
# Nama,Latitude,Longitude,Tipe,Deskripsi
# Lawang Sewu,-6.9840,110.4105,Wisata Sejarah,Bangunan bersejarah peninggalan Belanda dengan banyak pintu.
# Simpang Lima,-6.9929,110.4200,Landmark,Alun-alun pusat kota Semarang.
# Masjid Agung Jawa Tengah,-6.9892,110.4452,Tempat Ibadah,Masjid besar dengan arsitektur megah dan menara pandang.
# Klenteng Sam Poo Kong,-6.9980,110.4030,Tempat Ibadah,Klenteng bersejarah peninggalan Laksamana Cheng Ho.
# Brown Canyon,-7.0375,110.4875,Wisata Alam,Tebing bekas penambangan yang unik.
# Lumpia Gang Lombok,-6.9718,110.4255,Kuliner,Salah satu tempat makan lumpia legendaris.
# Kota Lama,-6.9690,110.4250,Wisata Sejarah,Kawasan cagar budaya bergaya Eropa.
# Pantai Marina,-6.9585,110.3875,Wisata Alam,Kawasan pantai rekreasi.
# Kampoeng Kopi Banaran,-7.2780,110.4010,Wisata Alam,Agrowisata kebun kopi.
# Toko Oen,-6.9715,110.4235,Kuliner,Restoran dan toko es krim legendaris.
# Museum Ronggowarsito,-6.9930,110.3970,Museum,Museum terbesar di Jawa Tengah.
# Museum Mandala Bhakti,-6.9835,110.4095,Museum,Museum perjuangan TNI.
# Taman KB,-6.9895,110.4215,Taman Kota,Taman rekreasi keluarga.
# Out:
# Overwriting lokasi_semarang.csv

# %% [markdown]
# #Praktikum 2: Membaca CSV dengan Pandas

# %%
import pandas as pd

NAMA_FILE_CSV = "lokasi_semarang.csv"

def baca_data_lokasi(nama_file: str) -> pd.DataFrame | None:
    print(f"Mencoba membaca file CSV: {nama_file}")
    try:
        dataframe = pd.read_csv(nama_file)
        print(" -> File CSV berhasil dibaca.")
        return dataframe
    except FileNotFoundError:
        print(f" -> ERROR: File '{nama_file}' tidak ditemukan!")
        return None
    except pd.errors.EmptyDataError:
        print(f" -> ERROR: File '{nama_file}' kosong.")
        return None
    except Exception as e:
        print(f" -> ERROR saat membaca file CSV: {e}")
        return None

# --- Main Program Praktikum 2 ---
df_lokasi = baca_data_lokasi(NAMA_FILE_CSV)

if df_lokasi is not None:
    print("\n1. Lima Baris Pertama (head()):")
    print(df_lokasi.head())

    print("\n2. Informasi DataFrame (info()):")
    df_lokasi.info()

    jumlah_baris, jumlah_kolom = df_lokasi.shape
    print(f"\n3. Dimensi Data:")
    print(f"   Jumlah Lokasi (Baris) : {jumlah_baris}")
    print(f"   Jumlah Atribut (Kolom): {jumlah_kolom}")
# Out:
# Mencoba membaca file CSV: lokasi_semarang.csv
#  -> File CSV berhasil dibaca.
#
# 1. Lima Baris Pertama (head()):
#                        Nama  Latitude  Longitude            Tipe  \
# 0               Lawang Sewu   -6.9840   110.4105  Wisata Sejarah
# 1              Simpang Lima   -6.9929   110.4200        Landmark
# 2  Masjid Agung Jawa Tengah   -6.9892   110.4452   Tempat Ibadah
# 3     Klenteng Sam Poo Kong   -6.9980   110.4030   Tempat Ibadah
# 4              Brown Canyon   -7.0375   110.4875     Wisata Alam
#
#                                            Deskripsi
# 0  Bangunan bersejarah peninggalan Belanda dengan...
# 1                     Alun-alun pusat kota Semarang.
# 2  Masjid besar dengan arsitektur megah dan menar...
# 3  Klenteng bersejarah peninggalan Laksamana Chen...
# 4                Tebing bekas penambangan yang unik.
#
# 2. Informasi DataFrame (info()):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
# ...

# %% [markdown]
# #Praktikum 3: Mendesain Kelas OOP

# %%
from abc import ABC, abstractmethod

class Lokasi(ABC):
    def __init__(self, nama: str, latitude: float, longitude: float):
        self.nama = str(nama) if nama else "Tanpa Nama"
        try:
            self.latitude = float(latitude)
            self.longitude = float(longitude)
        except (ValueError, TypeError):
            self.latitude = 0.0
            self.longitude = 0.0

    def get_koordinat(self) -> tuple:
        return (self.latitude, self.longitude)

    @abstractmethod
    def get_info_popup(self) -> str:
        pass

    def __repr__(self) -> str:
        return f"{type(self).__name__}(nama='{self.nama}', lat={self.latitude:.4f}, lon={self.longitude:.4f})"

class TempatWisata(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, jenis: str, deskripsi: str):
        super().__init__(nama, latitude, longitude)
        self.jenis_wisata = str(jenis) if jenis else "Umum"
        self.deskripsi = str(deskripsi) if deskripsi else "Tidak ada deskripsi."

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>{self.jenis_wisata}</i><br><br>{self.deskripsi}<br><br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class Kuliner(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, deskripsi: str):
        super().__init__(nama, latitude, longitude)
        self.deskripsi = str(deskripsi) if deskripsi else "Tidak ada deskripsi."

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>Kuliner</i><br><br>{self.deskripsi}<br><br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class TempatIbadah(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, deskripsi: str):
        super().__init__(nama, latitude, longitude)
        self.deskripsi = str(deskripsi) if deskripsi else "Tidak ada deskripsi."

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>Tempat Ibadah</i><br><br>{self.deskripsi}<br><br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class Museum(Lokasi):

    def __init__(self, nama, latitude, longitude, deskripsi):

        super().__init__(nama, latitude, longitude)

        self.deskripsi = deskripsi

    def get_info_popup(self):

        return f"""
        <b>{self.nama}</b><br>
        Museum<br>
        {self.deskripsi}
        """

class TamanKota(Lokasi):

    def __init__(self, nama, latitude, longitude, deskripsi):

        super().__init__(nama, latitude, longitude)

        self.deskripsi = deskripsi

    def get_info_popup(self):

        return f"""
        <b>{self.nama}</b><br>
        Taman Kota<br>
        {self.deskripsi}
        """

# %% [markdown]
# #Praktikum 4: Membuat Objek dari Data

# %%
def buat_objek_lokasi_dari_df(dataframe: pd.DataFrame) -> list:
    list_objek_lokasi = []
    if dataframe is None or dataframe.empty:
        return list_objek_lokasi

    for index, row in dataframe.iterrows():
        nama = row.get('Nama', None)
        lat = row.get('Latitude', None)
        lon = row.get('Longitude', None)
        tipe = row.get('Tipe', 'Lainnya')
        deskripsi = row.get('Deskripsi', '')

        if pd.isna(nama) or pd.isna(lat) or pd.isna(lon):
            continue

        try:
            if 'Wisata' in tipe or tipe == 'Landmark':
                objek = TempatWisata(nama, lat, lon, tipe, deskripsi)
            elif tipe == 'Kuliner':
                objek = Kuliner(nama, lat, lon, deskripsi)
            elif tipe == "Museum":
                objek = Museum(nama, lat, lon, deskripsi)
            elif tipe == "Taman Kota":
                objek = TamanKota(nama, lat, lon, deskripsi)
            elif 'Ibadah' in tipe:
                objek = TempatIbadah(nama, lat, lon, deskripsi)
            else:
                continue

            list_objek_lokasi.append(objek)
        except Exception as e:
            print(f" -> GAGAL membuat objek untuk '{nama}' di baris {index}: {e}")

    return list_objek_lokasi

# --- Main Program Praktikum 4 ---
list_semua_lokasi = buat_objek_lokasi_dari_df(df_lokasi)
print("\n--- Daftar Objek Lokasi yang Berhasil Dibuat ---")
for idx, lok in enumerate(list_semua_lokasi):
    print(f"{idx+1}. {repr(lok)}")
# Out:
# --- Daftar Objek Lokasi yang Berhasil Dibuat ---
# 1. TempatWisata(nama='Lawang Sewu', lat=-6.9840, lon=110.4105)
# 2. TempatWisata(nama='Simpang Lima', lat=-6.9929, lon=110.4200)
# 3. TempatIbadah(nama='Masjid Agung Jawa Tengah', lat=-6.9892, lon=110.4452)
# 4. TempatIbadah(nama='Klenteng Sam Poo Kong', lat=-6.9980, lon=110.4030)
# 5. TempatWisata(nama='Brown Canyon', lat=-7.0375, lon=110.4875)
# 6. Kuliner(nama='Lumpia Gang Lombok', lat=-6.9718, lon=110.4255)
# 7. TempatWisata(nama='Kota Lama', lat=-6.9690, lon=110.4250)
# 8. TempatWisata(nama='Pantai Marina', lat=-6.9585, lon=110.3875)
# 9. TempatWisata(nama='Kampoeng Kopi Banaran', lat=-7.2780, lon=110.4010)
# 10. Kuliner(nama='Toko Oen', lat=-6.9715, lon=110.4235)
# 11. Museum(nama='Museum Ronggowarsito', lat=-6.9930, lon=110.3970)
# 12. Museum(nama='Museum Mandala Bhakti', lat=-6.9835, lon=110.4095)
# 13. TamanKota(nama='Taman KB', lat=-6.9895, lon=110.4215)

# %% [markdown]
# konfigurasi baru

# %%
# %%writefile config_peta.txt
# -6.9929
# 110.4200
# 13
# Out:
# Overwriting config_peta.txt

# %% [markdown]
# membaca konfigurasi

# %%
def baca_config():

    try:

        with open(
            "config_peta.txt",
            "r"
        ) as file:

            baris = file.readlines()

        lat = float(baris[0])
        lon = float(baris[1])
        zoom = int(baris[2])

        return lat, lon, zoom

    except:

        return -6.9929, 110.4200, 13

# %% [markdown]
# #Praktikum 5: Visualisasi dengan Folium

# %%
import folium

def buat_peta_lokasi_folium(list_objek: list, file_output: str = "peta_lokasi.html"):
    if not list_objek:
        print("Gagal: Tidak ada data lokasi untuk dipetakan.")
        return None

    # Koordinat pusat awal (Semarang)
    peta = folium.Map(location=[-6.9929, 110.4200], zoom_start=13)

    jumlah_marker_valid = 0

    for lok in list_objek:

        koordinat = lok.get_koordinat()

        if koordinat != (0.0, 0.0):

            info_popup_html = lok.get_info_popup()

            warna = "blue"
            ikon = "info-sign"

            if isinstance(lok, TempatWisata):
                warna = "blue"
                ikon = "camera"

            elif isinstance(lok, Kuliner):
                warna = "red"
                ikon = "cutlery"

            elif isinstance(lok, TempatIbadah):
                warna = "green"
                ikon = "home"

            elif isinstance(lok, Museum):
                warna = "purple"
                ikon = "book"

            elif isinstance(lok, TamanKota):
                warna = "darkgreen"
                ikon = "tree-conifer"

            folium.Marker(
                location=koordinat,
                popup=folium.Popup(
                    info_popup_html,
                    max_width=300
                ),
                tooltip=lok.nama,
                icon=folium.Icon(
                    color=warna,
                    icon=ikon
                )
            ).add_to(peta)

            jumlah_marker_valid += 1

    try:
        peta.save(file_output)
        print(f"-> Peta berhasil disimpan sebagai '{file_output}'. Total marker: {jumlah_marker_valid}")
    except Exception as e:
        print(f"ERROR saat menyimpan peta Folium: {e}")

    return peta

# --- Main Program Praktikum 5 ---
peta_hasil = buat_peta_lokasi_folium(list_semua_lokasi, "peta_semarang.html")
# Memanggil objek peta agar langsung tampil secara interaktif di Google Colab
peta_hasil
# Out:
# -> Peta berhasil disimpan sebagai 'peta_semarang.html'. Total marker: 13
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #Praktikum 6: File Handling Tambahan (Log)

# %%
import datetime

def tulis_log(pesan: str, file_log: str = "proses_peta.log"):
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    try:
        with open(file_log, 'a', encoding='utf-8') as f:
            f.write(f"[{timestamp}] {pesan}\n")
    except IOError as e:
        print(f"ERROR: Gagal menulis ke file log '{file_log}': {e}")

def buat_peta_lokasi_folium_dengan_log(list_objek: list, file_output: str = "peta_lokasi.html", file_log: str = "proses_peta.log"):
    nama_fungsi = "buat_peta_lokasi_folium"
    tulis_log(f"[{nama_fungsi}] Memulai proses pembuatan peta.", file_log)

    if not list_objek:
        pesan_log = f"[{nama_fungsi}] Gagal: Tidak ada data lokasi untuk dipetakan."
        print(pesan_log)
        tulis_log(pesan_log, file_log)
        return None

    # Pastikan library folium sudah diimpor. Jika belum, tambahkan di awal sel atau notebook.
    # import folium # Asumsi sudah diimpor di sel sebelumnya atau user akan menambahkan.

    peta = folium.Map(location=[-6.9929, 110.4200], zoom_start=13)
    jumlah_marker_valid = 0

    for lok in list_objek:
        koordinat = lok.get_koordinat()
        if koordinat != (0.0, 0.0):
            info_popup_html = lok.get_info_popup()
            folium.Marker(
                location=koordinat,
                popup=folium.Popup(info_popup_html, max_width=300),
                tooltip=lok.nama
            ).add_to(peta)
            jumlah_marker_valid += 1
        else:
            tulis_log(f"[{nama_fungsi}] Peringatan: Melewati '{lok.nama}' karena koordinat tidak valid.", file_log)

    try:
        peta.save(file_output)
        pesan_sukses = f"[{nama_fungsi}] Sukses: Peta disimpan sebagai '{file_output}'. Total marker: {jumlah_marker_valid}"
        print(pesan_sukses)
        tulis_log(pesan_sukses, file_log)
    except Exception as e:
        pesan_error = f"[{nama_fungsi}] ERROR saat menyimpan peta: {e}"
        print(pesan_error)
        tulis_log(pesan_error, file_log)

    return peta

# --- Main Program Praktikum 6 ---
FILE_LOG = "proses_peta.log"

# Eksekusi fungsi pembuatan peta dengan log
peta_final = buat_peta_lokasi_folium_dengan_log(list_semua_lokasi, "peta_semarang_final.html", FILE_LOG)

# Menampilkan isi file log di Colab untuk pembuktian
print("\n--- Isi File Log (proses_peta.log) ---")
with open(FILE_LOG, "r") as f:
    print(f.read())
# Out:
# [buat_peta_lokasi_folium] Sukses: Peta disimpan sebagai 'peta_semarang_final.html'. Total marker: 13
#
# --- Isi File Log (proses_peta.log) ---
# [2026-06-25 13:39:30] [buat_peta_lokasi_folium] Memulai proses pembuatan peta.
# [2026-06-25 13:39:30] [buat_peta_lokasi_folium] Sukses: Peta disimpan sebagai 'peta_semarang_final.html'. Total marker: 10
# [2026-06-25 14:52:47] [buat_peta_lokasi_folium] Memulai proses pembuatan peta.
# [2026-06-25 14:52:47] [buat_peta_lokasi_folium] Sukses: Peta disimpan sebagai 'peta_semarang_final.html'. Total marker: 13
